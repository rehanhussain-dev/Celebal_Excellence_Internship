# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
# 🤖 AGENT FUNCTION (TO IMPLEMENT)

def agent(query: str):
    query_lower = query.lower()

    try:
        # 1. Math queries → Calculator Tool
        if "calculate" in query_lower:
            # Strip out "calculate" to pass only the expression to the tool
            expression = query.replace("Calculate", "").replace("calculate", "").strip()
            res = calculator(expression)

            if res == "Error in calculation":
                return {"type": "error", "result": res}
            return {"type": "calculation", "result": res}

        # 2. Keyword extraction → Keyword Tool
        elif "keywords" in query_lower:
            # Clean up introductory phrasing to pass cleaner text to the extractor
            text_to_extract = query.replace("Extract keywords from", "").replace("extract keywords from", "")
            text_to_extract = text_to_extract.replace("keywords", "").strip()

            res = extract_keywords(text_to_extract)
            return {"type": "keywords", "result": res}

        # 3. General queries → Direct response
        else:
            return {
                "type": "general",
                "result": f"This is a general query response for: '{query}'"
            }

    except Exception as e:
        return {
            "type": "error",
            "result": str(e)
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['artificial', 'industries', 'intelligence', 'transforming']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': "This is a general query response for: 'What is machine learning?'"}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): calculate 30+10
# Response: {'type': 'calculation', 'result': '40'}
# Enter query (type 'exit' to stop): keyword extraction: Machine Learning is interesting
# Response: {'type': 'general', 'result': "This is a general query response for: 'keyword extraction: Machine Learning is interesting'"}
# Enter query (type 'exit' to stop): keywords extraction: Machine learning is interesting
# Response: {'type': 'keywords', 'result': ['machine', 'learning', 'interesting', 'extraction:']}
# Enter query (type 'exit' to stop): exit
